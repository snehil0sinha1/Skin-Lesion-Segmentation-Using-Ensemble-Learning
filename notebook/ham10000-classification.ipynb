# %%
# Import required moduls/libs for our model
import numpy as np          # linear algebra
import pandas as pd         # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Dropout, Activation
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, \
     Dense, Input, Activation, Dropout, GlobalAveragePooling2D, AveragePooling2D
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Model
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import cv2
from cv2 import imread, resize # manipulating the images
from tensorflow.keras.optimizers import Adam
import os
# Out:
# 2024-05-07 13:45:44.473055: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-07 13:45:44.473164: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-07 13:45:44.609994: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Reading the meta date of our data frame.
df_skin = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
# Display the first 10 lines
df_skin.head(10)
# Out:
#      lesion_id      image_id   dx dx_type   age     sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0    male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0    male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0    male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0    male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0    male          ear
# 5  HAM_0001466  ISIC_0027850  bkl   histo  75.0    male          ear
# 6  HAM_0002761  ISIC_0029176  bkl   histo  60.0    male         face
# 7  HAM_0002761  ISIC_0029068  bkl   histo  60.0    male         face
# 8  HAM_0005132  ISIC_0025837  bkl   histo  70.0  female         back
# 9  HAM_0005132  ISIC_0025209  bkl   histo  70.0  female         back

# %%
# Lesion/dis names are given in the description of the data set.
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

lesion_ID_dict = {
    'nv': 0,
    'mel': 1,
    'bkl': 2,
    'bcc': 3,
    'akiec': 4,
    'vasc': 5,
    'df': 6
}

# Lesion and it's abbriv.
lesion_names = ['Melanocytic nevi','Melanoma','Benign keratosis-like lesions ',
               'Basal cell carcinoma','Actinic keratoses','Vascular lesions',
               'Dermatofibroma']
lesion_names_short = ['nv','mel','bkl','bcc','akiec','vasc','df']

# Maping the lesion type and ID to a dict.
df_skin['lesion_type']=df_skin['dx'].map(lesion_type_dict)
df_skin['lesion_ID'] = df_skin['dx'].map(lesion_ID_dict)

# Display the total found images.
print('Total number of images', len(df_skin))
print('The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels')

# Display the count of each lesion.
df_skin['lesion_type'].value_counts()
# Out:
# Total number of images 10015
# The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels
# lesion_type
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: count, dtype: int64

# %%
# Reading a random image from our data set
fname_images = np.array(df_skin['image_id'])
file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_images[13])+'.jpg'

# Resizing the read image to 100x100
img = imread(file_to_read)
img2 = resize(img, (100, 100))

# Show one exampe image before and after
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img[:, :, ::-1])
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(img2[:, :, ::-1])
plt.title('Resized image')
plt.show()

# %%
def produce_new_img(img2: cv2) -> tuple:
    """
    function to reproduse a new manipulated (rotating of flipping the original one)
    image from the read one, To increase the dimension of the dataset, avoiding overfitting of a single class.

    Args:
        img2 (cv2): the read image from cv2 module.

    Returns:
        new_images (tuple): a tuple of the new manipulated images.
    """
    imga = cv2.rotate(img2, cv2.ROTATE_90_CLOCKWISE)
    imgb = cv2.rotate(img2, cv2.ROTATE_90_COUNTERCLOCKWISE)
    imgc = cv2.rotate(img2, cv2.ROTATE_180)
    imgd = cv2.flip(img2, 0)
    imge = cv2.flip(img2, 1)
    new_imges = imga, imgb, imgc, imgd ,imge
    return new_imges

def show_example() -> None:
    """
    Display an image after manipulating it in produce_new_img() function
    """
    plt.figure(figsize = (10, 8))
    plt.subplot(2, 3, 1)
    plt.imshow(img2[:, :, ::-1])
    for i in range(5):
        plt.subplot(2, 3, 2+i)
        plt.imshow(new_img[i][:, :, ::-1])
    plt.tight_layout()
    plt.show()

# Invoking our function :)
new_img = produce_new_img(img2)
# Display an example by invoking show_example func
show_example()

# %%
x = []          # Hold resized images.
y = []          # Hold image lesion ID from the data set.

# Listing all files in the part_1, part_2 dirs
lista1 = os.listdir('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/')
lista2 = os.listdir('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/')

# [+] Handling images from part 1 directory
for i in range(len(lista1)):
    # [+] Features: reading and resize the photo.
    fname_image = lista1[i]
    fname_ID = fname_image.replace('.jpg', '')
    file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/' + str(fname_image)  # resolve image name
    img = imread(file_to_read)                                  # read the image 
    img2 = resize(img,(100, 100))                               # resise our image
    x.append(img2)                                              # append the new image to the list x.
    
    # Targets: Finding the image lesion ID and append it to the y list.
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # add more images for class between 1-6, rotating them 
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            x.append(new_img[i])
            y.append(output[0])

    # inform the user with the number of loaded images each 100 img.
    if i % 100 == 0:
        print(i, 'images loaded')


# [+] Handling images from part 2 directory
for i in range(len(lista2)):

    # [+] Features: reading and resize the photo.
    fname_image = lista2[i]
    fname_ID = fname_image.replace('.jpg', '')
    file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/' + str(fname_image)


    img = imread(file_to_read)
    img2 = resize(img, (100, 100))
    x.append(img2)
    
    # Targets: Finding the image lesion ID and append it to the y list.
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # [+] Add more images for class between 1-6
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            x.append(new_img[i])
            y.append(output[0])
    
    if i % 100 == 0: # [+] Inform the user with the number of loaded images each 100 img.
        print(len(lista1) + i,'images loaded')
# Out:
# 0 images loaded
# 100 images loaded
# 200 images loaded
# 300 images loaded
# 400 images loaded
# 500 images loaded
# 600 images loaded
# 700 images loaded
# 800 images loaded
# 1100 images loaded
# 1200 images loaded
# 1500 images loaded
# 1600 images loaded
# 1800 images loaded
# 2100 images loaded
# 2300 images loaded
# 2400 images loaded
# 2600 images loaded
# 2700 images loaded
# 2800 images loaded
# 2900 images loaded
# 3000 images loaded
# 3100 images loaded
# 3200 images loaded
# 3500 images loaded
# 3600 images loaded
# 3700 images loaded
# 3900 images loaded
# 4100 images loaded
# 4500 images loaded
# 4600 images loaded
# 4700 images loaded
# 4800 images loaded
# 4900 images loaded
# 5000 images loaded
# 5100 images loaded
# 5300 images loaded
# 5400 images loaded
# 5700 images loaded
# 5900 images loaded
# 6000 images loaded
# 6100 images loaded
# 6200 images loaded
# 6400 images loaded
# 6600 images loaded
# 6700 images loaded
# 6800 images loaded
# 6900 images loaded
# 7000 images loaded
# 7100 images loaded
# 7200 images loaded
# 7300 images loaded
# 7400 images loaded
# 7500 images loaded
# 7600 images loaded
# 7700 images loaded
# 7800 images loaded
# 8000 images loaded
# 8100 images loaded
# 8300 images loaded
# 8400 images loaded
# 8700 images loaded
# 8900 images loaded
# 9100 images loaded
# 9200 images loaded
# 9400 images loaded
# 9500 images loaded
# 9600 images loaded
# 9700 images loaded
# 9800 images loaded
# 9900 images loaded

# %%
x = np.array(x)
y = np.array(y)

# convert y (targets) array as required by softmax activation function
y_train = to_categorical(y, num_classes = 7)

# %%
# split in 80% training and 20% test data
X_train, X_test, y_train, y_test = train_test_split(x,                  # Images array.
                                                    y_train,            # The training set.
                                                    test_size = 0.20,   # Split data set into 20/80.
                                                    random_state = 50,  # Shuffling number to random the set.
                                                    stratify = y)       # Mix training and test sets.
# [+] Display the count of train/test data set.
print('Train dataset shape', X_train.shape)
print('Test dataset shape', X_test.shape)
# Out:
# Train dataset shape (21252, 100, 100, 3)
# Test dataset shape (5313, 100, 100, 3)

# %%
print('Train dataset shape', X_train.shape)
print('Test dataset shape', X_test.shape)
print('Test dataset shape', y_train.shape)
# Out:
# Train dataset shape (21252, 100, 100, 3)
# Test dataset shape (5313, 100, 100, 3)
# Test dataset shape (21252, 7)

# %%
def show_neg_figuers() -> None:
    """ Display negative figuers of the classes. """
    # Figure, Axes
    _, ax = plt.subplots(1, 7, figsize = (30, 30))
    for i in range(7):
        ax[i].set_axis_off()                                    # set the image to negative.
        ax[i].imshow(X_train[i])                                # Display the img.
        ax[i].set_title(lesion_names[np.argmax(y_train[i])])    # Set image title.

show_neg_figuers()

# %%
def est_class_weights(dis_id: np.array) -> dict:
    """Estimate class weights for unbalanced datasets.

    Args:
        dis_id (np.array): numpy array of dis IDs

    Returns:
        dict: Estimated class weights for for unbalanced datasets.
    """
    class_weights = np.around(compute_class_weight(class_weight = 'balanced', classes = np.unique(dis_id), y = y), 2)
    class_weights = dict(zip(np.unique(dis_id), class_weights))

y_id = np.array(df_skin['lesion_ID'])
new_class_weights = est_class_weights(y_id)
print('The problem is unbalanced. We need to provide class-weights')
print(new_class_weights)
# Out:
# The problem is unbalanced. We need to provide class-weights
# None

# %%
import keras
from keras.utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
import itertools
from tensorflow.keras.layers import BatchNormalization
from keras.utils import to_categorical # convert to one-hot-encoding

# %%
model = Sequential()
        
# [+] 1st convolutional layer
model.add(Conv2D(filters = 96,
                kernel_size = (11, 11),
                strides = (4, 4),
                activation = 'relu',
                input_shape = (100, 100, 3)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))

# [+] 2nd convolutional layer
model.add(Conv2D(filters = 256,
                kernel_size=(5, 5),
                strides=(1, 1),
                activation = 'relu',
                padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))

# [+] 3rd convolutional layer
model.add(Conv2D(filters = 384,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 padding="same"))
model.add(BatchNormalization())

# [+] 4th convolutional layer
model.add(Conv2D(filters = 384,
                kernel_size = (1, 1), 
                strides = (1, 1), 
                activation = 'relu', 
                padding = "same"))
model.add(BatchNormalization())

# [+] 5th convolutional layer
model.add(Conv2D(filters = 256, 
                kernel_size = (1, 1),
                strides = (1, 1),
                activation = 'relu',
                padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (3, 3), strides = (2, 2)))
              
model.add(Flatten())  # [+] Convert the Conv2D objects into one List.

# [+] 6th, Dense layer:
# From the Docs: 
# A Dense layer feeds all outputs from the previous layer to all its neurons,
# each neuron providing one output to the next layer.
# source: www.stackoverflow.com
model.add(Dense(4096, activation = 'relu'))
model.add(Dropout(0.5))
              
# [+] 7th Dense layer
model.add(Dense(4096, activation = 'relu'))
model.add(Dropout(0.5))
              
# [+] 8th output layer
model.add(Dense(7, activation = 'softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
##########################
### [+] Training phase ###
##########################

def mod_checkpoint_callback() -> None:
    """
    Saving our model
    
    Returns:
        None: Saving a checkpoint of the model.
    """
    
    trained_model = ModelCheckpoint(filepath = '/kaggle/working/model_100_class.keras',  # result file name
                             save_weights_only = False,     # Save all training results/params.
                             monitor = 'val_accuracy',      # check our model accuracy if it's step forward.
                             mode = 'auto',                 # enable auto save.
                             save_best_only = True,         # if ac_new > ac_old
                             verbose = 1)
    return trained_model

# Montoring the training procces in each epoch.
early_stopping_monitor = EarlyStopping(patience = 100, monitor = 'val_accuracy')

model_checkpoint_callback = mod_checkpoint_callback()

# Estimate the model data if it was big one.
optimizer = Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-3)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip = True, shear_range = 0.2)
datagen.fit(X_train)

batch_size = 32     # samples in the network at once.
epochs = 100        # epochs number.

# org model result data
history = model.fit(datagen.flow(X_train,y_train),
                    epochs = epochs,
                    batch_size = batch_size,
                    shuffle = True,
                    callbacks = [early_stopping_monitor, model_checkpoint_callback],
                    validation_data = (X_test, y_test),
                    class_weight = new_class_weights
                )
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/665 ━━━━━━━━━━━━━━━━━━━━ 30s 46ms/step - accuracy: 0.2743 - loss: 2.7859
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715089837.103568      74 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4424 - loss: 1.6663
# Epoch 1: val_accuracy improved from -inf to 0.30002, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 71s 88ms/step - accuracy: 0.4426 - loss: 1.6652 - val_accuracy: 0.3000 - val_loss: 1.5914
# Epoch 2/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5621 - loss: 1.1442
# Epoch 2: val_accuracy improved from 0.30002 to 0.56221, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 51s 76ms/step - accuracy: 0.5621 - loss: 1.1441 - val_accuracy: 0.5622 - val_loss: 1.0840
# Epoch 3/100
# 662/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5915 - loss: 1.0400
# Epoch 3: val_accuracy did not improve from 0.56221
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.5916 - loss: 1.0400 - val_accuracy: 0.5317 - val_loss: 1.2051
# Epoch 4/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6140 - loss: 0.9765
# Epoch 4: val_accuracy did not improve from 0.56221
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.6140 - loss: 0.9764 - val_accuracy: 0.5074 - val_loss: 1.2462
# Epoch 5/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6370 - loss: 0.9356
# Epoch 5: val_accuracy improved from 0.56221 to 0.60023, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.6370 - loss: 0.9355 - val_accuracy: 0.6002 - val_loss: 1.0137
# Epoch 6/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6408 - loss: 0.8973
# Epoch 6: val_accuracy did not improve from 0.60023
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.6408 - loss: 0.8973 - val_accuracy: 0.5189 - val_loss: 1.1780
# Epoch 7/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6543 - loss: 0.8722
# Epoch 7: val_accuracy did not improve from 0.60023
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.6543 - loss: 0.8721 - val_accuracy: 0.5362 - val_loss: 1.3018
# Epoch 8/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6701 - loss: 0.8248
# Epoch 8: val_accuracy did not improve from 0.60023
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.6701 - loss: 0.8248 - val_accuracy: 0.3911 - val_loss: 2.2058
# Epoch 9/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6856 - loss: 0.7893
# Epoch 9: val_accuracy did not improve from 0.60023
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.6856 - loss: 0.7892 - val_accuracy: 0.5001 - val_loss: 1.3772
# Epoch 10/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6990 - loss: 0.7639
# Epoch 10: val_accuracy did not improve from 0.60023
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.6991 - loss: 0.7639 - val_accuracy: 0.3787 - val_loss: 2.2822
# Epoch 11/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7087 - loss: 0.7341
# Epoch 11: val_accuracy improved from 0.60023 to 0.68492, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.7087 - loss: 0.7341 - val_accuracy: 0.6849 - val_loss: 0.8268
# Epoch 12/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7276 - loss: 0.6948
# Epoch 12: val_accuracy did not improve from 0.68492
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.7276 - loss: 0.6948 - val_accuracy: 0.5496 - val_loss: 1.2044
# Epoch 13/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7402 - loss: 0.6591
# Epoch 13: val_accuracy did not improve from 0.68492
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.7402 - loss: 0.6591 - val_accuracy: 0.6537 - val_loss: 0.9369
# Epoch 14/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7515 - loss: 0.6326
# Epoch 14: val_accuracy did not improve from 0.68492
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.7515 - loss: 0.6326 - val_accuracy: 0.4963 - val_loss: 1.7510
# Epoch 15/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7586 - loss: 0.6094
# Epoch 15: val_accuracy did not improve from 0.68492
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.7586 - loss: 0.6094 - val_accuracy: 0.6025 - val_loss: 1.1025
# Epoch 16/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7748 - loss: 0.5794
# Epoch 16: val_accuracy did not improve from 0.68492
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.7748 - loss: 0.5794 - val_accuracy: 0.6431 - val_loss: 1.0482
# Epoch 17/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7930 - loss: 0.5287
# Epoch 17: val_accuracy improved from 0.68492 to 0.71316, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.7930 - loss: 0.5288 - val_accuracy: 0.7132 - val_loss: 0.6995
# Epoch 18/100
# 662/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7930 - loss: 0.5340
# Epoch 18: val_accuracy improved from 0.71316 to 0.71918, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.7930 - loss: 0.5340 - val_accuracy: 0.7192 - val_loss: 0.8204
# Epoch 19/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8049 - loss: 0.4931
# Epoch 19: val_accuracy improved from 0.71918 to 0.72934, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.8049 - loss: 0.4932 - val_accuracy: 0.7293 - val_loss: 0.6811
# Epoch 20/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8206 - loss: 0.4649
# Epoch 20: val_accuracy improved from 0.72934 to 0.75212, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.8205 - loss: 0.4650 - val_accuracy: 0.7521 - val_loss: 0.6573
# Epoch 21/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8206 - loss: 0.4557
# Epoch 21: val_accuracy improved from 0.75212 to 0.75287, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 51s 75ms/step - accuracy: 0.8206 - loss: 0.4557 - val_accuracy: 0.7529 - val_loss: 0.6647
# Epoch 22/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8394 - loss: 0.4124
# Epoch 22: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8394 - loss: 0.4125 - val_accuracy: 0.6998 - val_loss: 0.9337
# Epoch 23/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8441 - loss: 0.4051
# Epoch 23: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8441 - loss: 0.4052 - val_accuracy: 0.7446 - val_loss: 0.6998
# Epoch 24/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8482 - loss: 0.3884
# Epoch 24: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8482 - loss: 0.3884 - val_accuracy: 0.5925 - val_loss: 1.3284
# Epoch 25/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8583 - loss: 0.3676
# Epoch 25: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8582 - loss: 0.3676 - val_accuracy: 0.7438 - val_loss: 0.6891
# Epoch 26/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8568 - loss: 0.3695
# Epoch 26: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8568 - loss: 0.3695 - val_accuracy: 0.6812 - val_loss: 1.0300
# Epoch 27/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8695 - loss: 0.3389
# Epoch 27: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8694 - loss: 0.3389 - val_accuracy: 0.6550 - val_loss: 1.0256
# Epoch 28/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8687 - loss: 0.3391
# Epoch 28: val_accuracy did not improve from 0.75287
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.8688 - loss: 0.3390 - val_accuracy: 0.6460 - val_loss: 1.3444
# Epoch 29/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8759 - loss: 0.3271
# Epoch 29: val_accuracy improved from 0.75287 to 0.76247, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.8759 - loss: 0.3271 - val_accuracy: 0.7625 - val_loss: 0.6700
# Epoch 30/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8835 - loss: 0.3129
# Epoch 30: val_accuracy improved from 0.76247 to 0.81649, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.8835 - loss: 0.3129 - val_accuracy: 0.8165 - val_loss: 0.5115
# Epoch 31/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8936 - loss: 0.2837
# Epoch 31: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.8936 - loss: 0.2838 - val_accuracy: 0.6885 - val_loss: 0.9920
# Epoch 32/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8987 - loss: 0.2669
# Epoch 32: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 48s 72ms/step - accuracy: 0.8986 - loss: 0.2669 - val_accuracy: 0.6571 - val_loss: 1.3355
# Epoch 33/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8915 - loss: 0.2819
# Epoch 33: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.8915 - loss: 0.2819 - val_accuracy: 0.7499 - val_loss: 0.7702
# Epoch 34/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8961 - loss: 0.2648
# Epoch 34: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.8961 - loss: 0.2648 - val_accuracy: 0.7403 - val_loss: 0.8818
# Epoch 35/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9070 - loss: 0.2508
# Epoch 35: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.9070 - loss: 0.2508 - val_accuracy: 0.7374 - val_loss: 0.8456
# Epoch 36/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9123 - loss: 0.2442
# Epoch 36: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.9123 - loss: 0.2442 - val_accuracy: 0.7580 - val_loss: 0.8051
# Epoch 37/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9143 - loss: 0.2313
# Epoch 37: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.9142 - loss: 0.2313 - val_accuracy: 0.7335 - val_loss: 0.9188
# Epoch 38/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9191 - loss: 0.2156
# Epoch 38: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.9191 - loss: 0.2156 - val_accuracy: 0.7901 - val_loss: 0.6993
# Epoch 39/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9204 - loss: 0.2180
# Epoch 39: val_accuracy did not improve from 0.81649
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - accuracy: 0.9204 - loss: 0.2180 - val_accuracy: 0.7384 - val_loss: 0.9792
# Epoch 40/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9159 - loss: 0.2235
# Epoch 40: val_accuracy improved from 0.81649 to 0.88425, saving model to /kaggle/working/model_100_class.keras
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 51s 76ms/step - accuracy: 0.9159 - loss: 0.2235 - val_accuracy: 0.8842 - val_loss: 0.3365
# Epoch 41/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9267 - loss: 0.1983
# Epoch 41: val_accuracy did not improve from 0.88425
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 48s
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.9759 - loss: 0.0711 - val_accuracy: 0.9093 - val_loss: 0.3286
# Epoch 99/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9745 - loss: 0.0694
# Epoch 99: val_accuracy did not improve from 0.91681
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 74ms/step - accuracy: 0.9745 - loss: 0.0694 - val_accuracy: 0.7913 - val_loss: 0.8572
# Epoch 100/100
# 663/665 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9787 - loss: 0.0615
# Epoch 100: val_accuracy did not improve from 0.91681
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 50s 75ms/step - accuracy: 0.9787 - loss: 0.0615 - val_accuracy: 0.8579 - val_loss: 0.5628

# %%
# [+] inform the user with model Accuracy %
scores = model.evaluate(X_test, y_test, verbose = 1)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8507 - loss: 0.5464
# Accuracy: 85.79%

# %%
def display_accuracy() -> None:
    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
    plt.show()

def display_loss() -> None:
    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

display_accuracy()
display_loss()

# %%
y_pred = model.predict(X_test)

def test_model() -> tuple:
    """ Tunning the accurate results and inaccurate results

    Returns:
        (total, accurate) [tuple]: tuple of total tested test-cases, accurate
    """
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []
    for i in range(len(y_pred)):
        if np.argmax(y_pred[i]) == np.argmax(y_test[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1
    return (total, accurate)

total, accurate = test_model()
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate / total * 100, 3), '%')
# Out:
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Total-test-data; 5313 	accurately-predicted-data: 4558 	 wrongly-predicted-data:  755
# Accuracy: 85.79 %

# %%
best_model = load_model('/kaggle/working/model_100_class.keras')

# Compute predictions
y_pred_prob = np.around(best_model.predict(X_test),3)
y_pred = np.argmax(y_pred_prob, axis = 1)
y_test2 = np.argmax(y_test, axis = 1)
# Out:
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
# [+] inform the user with model Accuracy %
scores = best_model.evaluate(X_test, y_test, verbose = 1)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9169 - loss: 0.2598
# Accuracy: 91.68%

# %%
plt.figure(figsize=(16,16))
for i in range(16):
    plt.subplot(4,4,i+1)
    index = i+100
    plt.imshow(X_test[index,:,:,::-1])
    label_exp = lesion_names[y_test2[index]]  #expected label
    label_pred = lesion_names[y_pred[index]]  #predicted label
    label_pred_prob = round(np.max(y_pred_prob[index])*100)
    plt.title('Expected:'+str(label_exp)+'\n Pred.:'+str(label_pred)+' ('+str(label_pred_prob)+'%)')
plt.ylabel('')
plt.tight_layout()
plt.savefig('final_figure.png',dpi=300)
plt.show()

# %%
#Accuracy for each type
acc_tot= []

for i in range(7):
    acc_parz = round(np.mean(y_test2[y_test2 == i] == y_pred[y_test2 == i]),2)
    lab_parz = lesion_names[i]
    print('accuracy for',lab_parz,'=',acc_parz)
    acc_tot.append(acc_parz)
# Out:
# accuracy for Melanocytic nevi = 0.86
# accuracy for Melanoma = 0.94
# accuracy for Benign keratosis-like lesions  = 0.93
# accuracy for Basal cell carcinoma = 0.96
# accuracy for Actinic keratoses = 0.88
# accuracy for Vascular lesions = 0.98
# accuracy for Dermatofibroma = 0.93

# %%
acc_tot = np.array(acc_tot)
freq = np.unique(y_test2,return_counts=True)[1]

np.sum(acc_tot*freq)/np.sum(freq)
# Out:
# 0.9162412949369473
